# %%
# import modules
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from bs4 import BeautifulSoup
import pandas as pd
import ethnicolr as ec
from pathlib import Path

# open browser and go to directory
driver = str(Path().resolve().parents[2]) + "\Tools\geckodriver.exe"
browser = webdriver.Firefox(executable_path=driver)
browser.get('https://www1.ocadu.ca/directory/')

# use BeautifulSoup to parse raw code
soup=BeautifulSoup(browser.page_source,'lxml')

# close browser
browser.quit()

# dictionary to hold data
data = {
    'First Name' : [],
    'Last Name' : [],
    'Email' : []
}

# find data
profs = soup.find("table", id="directory").find("tbody")

# iterate through each person
for prof in profs.findAll("tr"):
    # obtain contact info
    full_name = None
    email = None
    try:
        full_name = prof.find("td", class_="name").find("strong").find("span").find("a").get_text().split()
        email = prof.find("td", class_="name").find("em").get_text()
    except AttributeError:
        full_name = prof.find("td", class_="name").find("strong").find("span").find("strong").get_text().split()
        email = "No Email"
    print(full_name)
    fname = full_name[1]
    lname = full_name[0][:len(full_name[0])-1]
    
    # store contact info in data dictionary
    data['First Name'] += [fname]
    data['Last Name'] += [lname]
    data['Email'] += [email]

    # print contact info
    print(fname, lname, email)

# formatting
print()

# create pandas dataframe and remove any duplicate entries
df = pd.DataFrame(data)
df = df.drop_duplicates()
    
# determine ethnicity
df = ec.pred_wiki_name(df,list(df)[1],list(df)[0])
    
# print dataframe and write data to csv file
print(df)
df.to_csv("ocad parsed.csv")
# Out:
# ['Adams,', 'Debbie']
# Debbie Adams dadams@faculty.ocadu.ca
# ['Adams,', 'Kathryn']
# Kathryn Adams kadams@faculty.ocadu.ca
# ['Adatia,', 'Irfaan']
# Irfaan Adatia iadatia@ocadu.ca
# ['Addeo,', 'Stephen']
# Stephen Addeo saddeo@faculty.ocadu.ca
# ['Adler-Gitalis,', 'Sharyn']
# Sharyn Adler-Gitalis sadlergitalis@faculty.ocadu.ca
# ['Ahrens-Embleton,', 'Anne']
# Anne Ahrens-Embleton aahrensembleton@ocadu.ca
# ['Akbary,', 'Sayeda']
# Sayeda Akbary sakbary@ocadu.ca
# ['Alber,', 'Beth']
# Beth Alber No Email
# ['Aleong,', 'Tamara']
# Tamara Aleong taleong@ocadu.ca
# ['Allen,', 'Gale']
# Gale Allen gallen@ocadu.ca
# ['Allen,', 'Kristen']
# Kristen Allen kallen@ocadu.ca
# ['Allen,', 'Lillian']
# Lillian Allen lallen@faculty.ocadu.ca
# ['Allen,', 'Lisa']
# Lisa Allen lisaallen@ocadu.ca
# ['Aloisi,', 'Paul']
# Paul Aloisi paloisi@faculty.ocadu.ca
# ['Alvarez,', 'Francisco']
# Francisco Alvarez falvarez@ocadu.ca
# ['Amani,', 'Golboo']
# Golboo Amani gamani@faculty.ocadu.ca
# ['Amir,', 'Haider']
# Haider Amir haideramir@faculty.ocadu.ca
# ['Anderson,', 'Midnight']
# Midnight Anderson equity@ocadsu.org
# ['Angarita,', 'Luis']
# Luis Angarita langarita@faculty.ocadu.ca
# ['Angeles,', 'Angelica']
# Angelica Angeles aangeles@ocadu.ca
# ['Anoushah', 'Pour,', 'Faraz']
# Pour, Anousha farazanoushahpour@faculty.ocadu.ca
# ['Anstice,', 'Martyn']
# Martyn Anstice manstice@faculty.ocadu.ca
# ['Antkowiak,', 'Michael']
# Michael Antkowiak mantkowiak@faculty.ocadu.ca
# ['Aoki,', 'Nicholas']
# Nicholas Aoki naoki@faculty.ocadu.ca
# ['Araya,', 'Alvaro']
# Alvaro Araya aaraya@ocadu.ca
# ['Arcega,', 'Kristen']
# Kristen Arcega karcega@ocadu.ca
# ['Arezes', 'de', 'Sa,', 'Diana']
# de Areze darezesdesa@ocadu.ca
# ['Arezes-Reis,', 'Connie']
# Connie Arezes-Reis carezesreis@ocadu.ca
# ['Armstrong,', 'Vanessa']
# Vanessa Armstrong varmstrong@ocadu.ca
# ['Ascencao,', 'Teresa']
# Teresa Ascencao tascencao@faculty.ocadu.ca
# ['Ashby,', 'Madeline']
# Madeline Ashby mashby@faculty.ocadu.ca
# ['Asnani,', 'Shailen']
# Shailen Asnani sasnani@ocadu.ca
# ['Astman,', 'Barbara']
# Barbara Astman bastman@faculty.ocadu.ca
# ['Astrug,', 'Michelle']
# Michelle Astrug mastrug@faculty.ocadu.ca
# ['Atluri,', 'Tara']
# Tara Atluri tatluri@faculty.ocadu.ca
# ['Avery,', 'Joshua']
# Joshua Avery javery@faculty.ocadu.ca
# ['Avery,', 'Joshua']
# Joshua Avery javery@faculty.ocadu.ca
# ['Aydemir,', 'Mehnaz']
# Mehnaz Aydemir maydemir@faculty.ocadu.ca
# ['Ayotte,', 'Dana']
# Dana Ayotte dayotte@ocadu.ca
# ['Ayre,', 'Dominic']
# Dominic Ayre dayre@faculty.ocadu.ca
# ['Aysola,', 'Aruna']
# Aruna Aysola aaysola@ocadu.ca
# ['Azulay,', 'Michael']
# Michael Azulay mazulay@faculty.ocadu.ca
# ['Back,', 'Douglas']
# Douglas Back dback@faculty.ocadu.ca
# ['Bacnis,', 'Victoria']
# Victoria Bacnis vbacnis@ocadu.ca
# ['Badour,', 'Mike']
# Mike Badour mbadour@ocadu.ca
# ['Badovinac,', 'Jano']
# Jano Badovinac jbadovinac@faculty.ocadu.ca
# ['Baerg,', 'Jason']
# Jason Baerg jbaerg@faculty.ocadu.ca
# ['Bailey,', 'Stephanie']
# Stephanie Bailey sbailey@ocadu.ca
# ['Bain,', 'Donna']
# Donna Bain dbain@faculty.ocadu.ca
# ['Baker,', 'Sean']
# Sean Baker sbaker@ocadu.ca
# ['Balabanoff,', 'Doreen']
# Doreen Balabanoff dbalabanoff@faculty.ocadu.ca
# ['Barhad,', 'Koby']
# Koby Barhad kbarhad@faculty.ocadu.ca
# ['Bariteau,', 'Nadine']
# Nadine Bariteau nbariteau@faculty.ocadu.ca
# ['Barnes,', 'Sandra']
# Sandra Barnes sbarnes@ocadu.ca
# ['Bartleman,', 'Claire']
# Claire Bartleman cbartleman@faculty.ocadu.ca
# ['Bartleman,', 'Claire']
# Claire Bartleman cbartleman@faculty.ocadu.ca
# ['Bates,', 'Simon']
# Simon Bates sbates@ocadu.ca
# ['Bauer,', 'Greg']
# Greg Bauer gbauer@faculty.ocadu.ca
# ['Beaulieu,', 'Carole']
# Carole Beaulieu cbeaulieu@ocadu.ca
# ['Bennell,', 'Christopher']
# Christopher Bennell cbennell@ocadu.ca
# ['Bereza,', 'Adam']
# Adam Bereza abereza@ocadu.ca
# ['Bernal', 'Gomez,', 'Gloria']
# Gomez, Berna gbernalgomez@ocadu.ca
# ['Bertram,', 'Samantha']
# Samantha Bertram sbertram@ocadu.ca
# ['Bhatt,', 'Parantap']
# Parantap Bhatt pbhatt@faculty.ocadu.ca
# ['Biedron,', 'Darryl']
# Darryl Biedron darrylbiedron@faculty.ocadu.ca
# ['Bissett,', 'Tara']
# Tara Bissett tbissett@faculty.ocadu.ca
# ['Black,', 'Catherine']
# Catherine Black cblack@faculty.ocadu.ca
# ['Blanchard,', 'Philippe']
# Philippe Blanchard pblanchard@faculty.ocadu.ca
# ['Blanchard,', 'Philippe']
# Philippe Blanchard pblanchard@faculty.ocadu.ca
# ['Blum,', 'Annette']
# Annette Blum ablum@faculty.ocadu.ca
# ['Bodirsky,', 'Monica']
# Monica Bodirsky mbodirsky@faculty.ocadu.ca
# ['Bodunrin,', 'Adetokunbo']
# Adetokunbo Bodunrin abodunrin@faculty.ocadu.ca
# ['Bolt,', 'Laura']
# Laura Bolt lbolt@faculty.ocadu.ca
# ['Bouabane,', 'Kotama']
# Kotama Bouabane kbouabane@faculty.ocadu.ca
# ['Bowes,', 'Jeremy']
# Jeremy Bowes jbowes@faculty.ocadu.ca
# ['Bowes,', 'Tanya']
# Tanya Bowes tbowes@ocadu.ca
# ['Bowyer,', 'Peter']
# Peter Bowyer pbowyer@faculty.ocadu.ca
# ['Braccio,', 'Aldo']
# Aldo Braccio abraccio@faculty.ocadu.ca
# ['Braden,', 'Christopher']
# Christopher Braden cbraden@faculty.ocadu.ca
# ['Brancato,', 'Emilie']
# Emilie Brancato ebrancato@ocadu.ca
# ['Branya,', 'Beatrix']
# Beatrix Branya bbranya@faculty.ocadu.ca
# ['Brent,', 'Kieran']
# Kieran Brent kbrent@faculty.ocadu.ca
# ['Bresnahan,', 'Keith']
# Keith Bresnahan kbresnahan@faculty.ocadu.ca
# ['Bresnahan,', 'Keith']
# Keith Bresnahan kbresnahan@faculty.ocadu.ca
# ['Briker,', 'Daniel']
# Daniel Briker dbriker@faculty.ocadu.ca
# ['Brock,', 'Sascha']
# Sascha Brock sbrock@ocadu.ca
# ['Brown,', 'Adam', 'David']
# Adam Brown adambrown@faculty.ocadu.ca
# ['Browning,', 'Katherine']
# Katherine Browning kbrowning@ocadu.ca
# ['Brunet,', 'Claire']
# Claire Brunet cbrunet@faculty.ocadu.ca
# ['Brunet,', 'Claire']
# Claire Brunet cbrunet@faculty.ocadu.ca
# ['Buchanan,', 'Tracy']
# Tracy Buchanan tbuchanan@ocadu.ca
# ['Buczolits,', 'Emerson']
# Emerson Buczolits ebuczolits@ocadu.ca
# ['Bulbulia,', 'Solly']
# Solly Bulbulia sbulbulia@faculty.ocadu.ca
# ['Bullen,', 'Ross']
# Ross Bullen rbullen@faculty.ocadu.ca
# ['Burbach,', 'Frederick']
# Frederick Burbach fburbach@faculty.ocadu.ca
# ['Burke,', 'Donald']
# Donald Burke dburke@faculty.ocadu.ca
# ['Burke,', 'Tarah']
# Tarah Burke tburke@faculty.ocadu.ca
# ['Butterill,', 'Sarah']
# Sarah Butterill sbutterill@ocadu.ca
# ['Caines,', 'Clifford']
# Clifford Caines ccaines@faculty.ocadu.ca
# ['Campbell,', 'Colin']
# Colin Campbell ccampbell@faculty.ocadu.ca
# ['Campbell,', 'Susan']
# Susan Campbell scampbell@faculty.ocadu.ca
# ['Campea,', 'Anthony']
# Anthony Campea acampea@faculty.ocadu.ca
# ['Cao,', 'Chen']
# Chen Cao ccao@faculty.ocadu.ca
# ['Cao,', 'Yang']
# Yang Cao ycao@faculty.ocadu.ca
# ['Cao,', 'Yang']
# Yang Cao ycao@faculty.ocadu.ca
# ['Cappon,', 'Cathy']
# Cathy Cappon ccappon@ocadu.ca
# ['Carabott,', 'Claire']
# Claire Carabott ccarabott@ocadu.ca
# ['Carr-Harris,', 'Ian']
# Ian Carr-Harris icarrharris@faculty.ocadu.ca
# ['Carreiro,', 'Linda']
# Linda Carreiro lcarreiro@ocadu.ca
# ['Carreiro,', 'Linda']
# Linda Carreiro lcarreiro@ocadu.ca
# ['Carson,', 'Rebekah']
# Rebekah Carson rcarson@faculty.ocadu.ca
# ['Casasanta,', 'Maryanne']
# Maryanne Casasanta mcasasanta@ocadu.ca
# ['Casiez,', 'Lorene']
# Lorene Casiez lcasiez@faculty.ocadu.ca
# ['Cassady,', 'Jack']
# Jack Cassady jcassady@faculty.ocadu.ca
# ['Castillo,', 'Joel']
# Joel Castillo jcastillo@faculty.ocadu.ca
# ['Castledine,', 'Michael']
# Michael Castledine mcastledine@faculty.ocadu.ca
# ['Centeno,', 'Hector']
# Hector Centeno hcenteno@faculty.ocadu.ca
# ['Cerquera-Benjumea,', 'Gustavo']
# Gustavo Cerquera-Benjumea gcerquerabenjumea@faculty.ocadu.ca
# ['Chadha,', 'Kartikay']
# Kartikay Chadha kchadha@faculty.ocadu.ca
# ['Chagpar,', 'Anjum']
# Anjum Chagpar achagpar@faculty.ocadu.ca
# ['Chahine,', 'Marwan']
# Marwan Chahine mchahine@faculty.ocadu.ca
# ['Chakrabarty,', 'Ananda']
# Ananda Chakrabarty achakrabarty@faculty.ocadu.ca
# ['Chan,', 'Lesley']
# Lesley Chan lchan@faculty.ocadu.ca
# ['Chan,', 'Lillian']
# Lillian Chan lillianchan@ocadu.ca
# ['Chan,', 'Mitchell']
# Mitchell Chan mchan@faculty.ocadu.ca
# ['Chan,', 'Peter']
# Peter Chan pchan@faculty.ocadu.ca
# ['Chan-Dow,', 'Elaine']
# Elaine Chan-Dow echandow@faculty.ocadu.ca
# ['Chandler,', 'Zan']
# Zan Chandler zanchandler@faculty.ocadu.ca
# ['Chang,', 'Shea']
# Shea Chang schang@faculty.ocadu.ca
# ['Charbonneau,', 'Erica']
# Erica Charbonneau rcharbonneau@faculty.ocadu.ca
# ['Charbonneau,', 'Marie']
# Marie Charbonneau mcharbonneau@faculty.ocadu.ca
# ['Charlap,', 'Bruce']
# Bruce Charlap bcharlap@faculty.ocadu.ca
# ['Chau,', 'Wesley']
# Wesley Chau wchau@faculty.ocadu.ca
# ['Chen,', 'Carlina']
# Carlina Chen cchen@ocadu.ca
# ['Chen,', 'Jack']
# Jack Chen jchen@ocadu.ca
# ['Chisholm,', 'Connie']
# Connie Chisholm cchisholm@faculty.ocadu.ca
# ['Chu,', 'Shao-Pin']
# Shao-Pin Chu schu@faculty.ocadu.ca
# ['Chudolinska,', 'Marta']
# Marta Chudolinska mchudolinska@ocadu.ca
# ['Chung,', 'Karen']
# Karen Chung kchung@ocadu.ca
# ['Ciccotosto,', 'Fernando']
# Fernando Ciccotosto fciccotosto@ocadu.ca
# ['Clark,', 'Colin']
# Colin Clark cclark@ocadu.ca
# ['Clarke,', 'Ian']
# Ian Clarke iclarke@faculty.ocadu.ca
# ['Clarke,', 'Ian']
# Ian Clarke iclarke@faculty.ocadu.ca
# ['Clarke,', 'Trudy-Ann']
# Trudy-Ann Clarke tclarke@ocadu.ca
# ['Clarkson,', 'David']
# David Clarkson dclarkson@faculty.ocadu.ca
# ['Clydesdale,', 'Elizabeth']
# Elizabeth Clydesdale eclydesdale@ocadu.ca
# ['Cober,', 'Steve']
# Steve Cober scober@faculty.ocadu.ca
# ['Cobham,', 'Laura']
# Laura Cobham lcobham@ocadu.ca
# ['Coburn,', 'Tavis']
# Tavis Coburn tcoburn@faculty.ocadu.ca
# ['Coffey,', 'Heather']
# Heather Coffey hcoffey@faculty.ocadu.ca
# ['Cohen,', 'Arlene']
# Arlene Cohen acohen@faculty.ocadu.ca
# ['Cole,', 'Janis']
# Janis Cole jcole@faculty.ocadu.ca
# ['Collins,', 'Nicole']
# Nicole Collins ncollins@faculty.ocadu.ca
# ['Collyer,', 'Miles']
# Miles Collyer mcollyer@ocadu.ca
# ['Columbus,', 'Linda']
# Linda Columbus lcolumbus@ocadu.ca
# ['Connoy,', 'Richard']
# Richard Connoy rconnoy@ocadu.ca
# ['Constantinou,', 'Katina']
# Katina Constantinou kconstantinou@faculty.ocadu.ca
# ['Coodin,', 'Dave']
# Dave Coodin No Email
# ['Coppin,', 'Peter']
# Peter Coppin pcoppin@faculty.ocadu.ca
# ['Coppin,', 'Peter']
# Peter Coppin pcoppin@faculty.ocadu.ca
# ['Cotter,', 'Sam']
# Sam Cotter scotter@faculty.ocadu.ca
# ['Couchie,', 'Aylan']
# Aylan Couchie acouchie@faculty.ocadu.ca
# ['Coull,', 'John']
# John Coull jcoull@faculty.ocadu.ca
# ['Courtney,', 'Neil']
# Neil Courtney ncourtney@ocadu.ca
# ['Crockard,', 'Liam']
# Liam Crockard lcrockard@ocadu.ca
# ['Crooks,', 'Julie']
# Julie Crooks jcrooks@faculty.ocadu.ca
# ['Cropley,', 'Nicole']
# Nicole Cropley finance@ocadsu.org
# ['Currie,', 'Sarah']
# Sarah Currie scurrie@ocadu.ca
# ['Currington,', 'Darrell']
# Darrell Currington dcurrington@faculty.ocadu.ca
# ["D'Souza,", 'Lynn']
# Lynn D'Souza ldsouza@ocadu.ca
# ["D'Souza,", 'Michelle']
# Michelle D'Souza mdsouza@ocadu.ca
# ['Daley,', 'Cathy']
# Cathy Daley cdaley@faculty.ocadu.ca
# ['Dallas,', 'Paul']
# Paul Dallas pdallas@faculty.ocadu.ca
# ['Damery,', 'Greg']
# Greg Damery gdamery@faculty.ocadu.ca
# ['Dammermann,', 'Dylan']
# Dylan Dammermann ddammermann@ocadu.ca
# ['Dao,', 'Le']
# Le Dao ldao@ocadu.ca
# ['Darby,', 'Christopher']
# Christopher Darby cdarby@ocadu.ca
# ['Davila,', 'Patricio']
# Patricio Davila pdavila@faculty.ocadu.ca
# ['Davis,', 'Nicky']
# Nicky Davis ndavis@ocadu.ca
# ['Dawson,', 'Rosie']
# Rosie Dawson rdawson@faculty.ocadu.ca
# ['Dayes,', 'Stephanie']
# Stephanie Dayes sdayes@ocadu.ca
# ['De', 'Freitas,', 'Andre']
# Freitas, D adefreitas@ocadu.ca
# ['Deal,', 'John']
# John Deal jdeal@ocadu.ca
# ['Deal,', 'John']
# John Deal jdeal@ocadu.ca
# ['Dean,', 'Skip']
# Skip Dean sdean@faculty.ocadu.ca
# ['Del', 'Buono,', 'Angela']
# Buono, De adelbuono@faculty.ocadu.ca
# ['Delaviz,', 'Yasaman']
# Yasaman Delaviz ydelaviz@faculty.ocadu.ca
# ['Desai,', 'Maya']
# Maya Desai mdesai@faculty.ocadu.ca
# ['Desai,', 'Maya']
# Maya Desai mdesai@faculty.ocadu.ca
# ['Devine,', 'Bonnie']
# Bonnie Devine bdevine@faculty.ocadu.ca
# ['Dewan,', 'Rakhi']
# Rakhi Dewan rakhidewan@ocadu.ca
# ['Diamond,', 'Sara']
# Sara Diamond sdiamond@ocadu.ca
# ['Diaz', 'Sanchez,', 'Samara']
# Sanchez, Dia sdiazsanchez@ocadu.ca
# ['Dickinson,', 'Kelly']
# Kelly Dickinson kdickinson@ocadu.ca
# ['Diederichs,', 'Rebecca']
# Rebecca Diederichs rdiederichs@ocadu.ca
# ['Diederichs,', 'Rebecca']
# Rebecca Diederichs rdiederichs@ocadu.ca
# ['Diessel,', 'John']
# John Diessel jdiessel@faculty.ocadu.ca
# ['Dietz,', 'Bernhard']
# Bernhard Dietz bdietz@faculty.ocadu.ca
# ['Dion', 'Fletcher,', 'Vanessa']
# Fletcher, Dio vdionfletcher@faculty.ocadu.ca
# ['Dipietro,', 'Cary']
# Cary Dipietro cdipietro@ocadu.ca
# ['Docherty,', 'George']
# George Docherty gdocherty@faculty.ocadu.ca
# ['Doherty,', 'Joe']
# Joe Doherty jdoherty@ocadu.ca
# ['Doherty,', 'Shauna']
# Shauna Doherty sdoherty@ocadu.ca
# ['Doherty,', 'Shauna']
# Shauna Doherty sdoherty@ocadu.ca
# ['Dominguez,', 'Rick', 'James']
# Rick Dominguez rdominguez@faculty.ocadu.ca
# ['Dominguez-Tejo,', 'Julio']
# Julio Dominguez-Tejo jdominguez@ocadu.ca
# ['Doughty,', 'Tom']
# Tom Doughty tdoughty@faculty.ocadu.ca
# ['Doyle,', 'Judith']
# Judith Doyle jdoyle@faculty.ocadu.ca
# ['Doyle,', 'Judith']
# Judith Doyle jdoyle@faculty.ocadu.ca
# ['Doyle,', 'Susan']
# Susan Doyle sdoyle@ocadu.ca
# ['Drain,', 'Alea']
# Alea Drain adrain@ocadu.ca
# ['Drawson,', 'Blair']
# Blair Drawson bdrawson@faculty.ocadu.ca
# ['Drobnick,', 'Jim']
# Jim Drobnick jdrobnick@faculty.ocadu.ca
# ['Duffield,', 'Kyle']
# Kyle Duffield kduffield@faculty.ocadu.ca
# ['Dunkelman,', 'Avi']
# Avi Dunkelman adunkelman@faculty.ocadu.ca
# ['Dutt,', 'Puneet']
# Puneet Dutt pdutt@ocadu.ca
# ['Dywan,', 'Beverly']
# Beverly Dywan bdywan@faculty.ocadu.ca
# ['Edghill,', 'Phillip']
# Phillip Edghill pedghill@ocadu.ca
# ['Eggebeen,', 'Janna']
# Janna Eggebeen jeggebeen@faculty.ocadu.ca
# ['Ellis,', 'Barry']
# Barry Ellis bellis@ocadu.ca
# ['Epp,', 'Paul']
# Paul Epp pepp@faculty.ocadu.ca
# ['Erickson,', 'Loree']
# Loree Erickson lerickson@faculty.ocadu.ca
# ['Erlebach,', 'Franziska']
# Franziska Erlebach ferlebach@faculty.ocadu.ca
# ['Ernst,', 'Raelene']
# Raelene Ernst rernst@ocadu.ca
# ['Espiritu,', 'Noel']
# Noel Espiritu nespiritu@ocadu.ca
# ['Evelyn,', 'Heather']
# Heather Evelyn hevelyn@ocadu.ca
# ['Everingham,', 'Scott']
# Scott Everingham severingham@faculty.ocadu.ca
# ['Faller,', 'Kelly']
# Kelly Faller kfaller@ocadu.ca
# ['Farber,', 'Zev']
# Zev Farber zfarber@ocadu.ca
# ['Farber,', 'Zev']
# Zev Farber zfarber@ocadu.ca
# ['Farmer,', 'George']
# George Farmer gfarmer@faculty.ocadu.ca
# ['Farow,', 'Khadija']
# Khadija Farow advocate@ocadsu.org
# ['Fatona,', 'Andrea']
# Andrea Fatona afatona@faculty.ocadu.ca
# ['Fatona,', 'Andrea']
# Andrea Fatona afatona@faculty.ocadu.ca
# ['Feldman-Kiss,', 'Nichola']
# Nichola Feldman-Kiss nfeldmankiss@faculty.ocadu.ca
# ['Fenton,', 'Mitchell']
# Mitchell Fenton mfenton@faculty.ocadu.ca
# ['Fenuta,', 'Angelene']
# Angelene Fenuta afenuta@faculty.ocadu.ca
# ['Feraday-Miller,', 'Cathy']
# Cathy Feraday-Miller cferadaymiller@faculty.ocadu.ca
# ['Ferguson,', 'Susan']
# Susan Ferguson sferguson@ocadu.ca
# ['Fierro,', 'Monica']
# Monica Fierro mfierro@ocadu.ca
# ['Finley,', 'Erin']
# Erin Finley efinley@faculty.ocadu.ca
# ['Fishauf,', 'Louis']
# Louis Fishauf lfishauf@faculty.ocadu.ca
# ['Fisher,', 'Deanne']
# Deanne Fisher dfisher@ocadu.ca
# ['Fletcher,', 'Alanna']
# Alanna Fletcher afletcher@ocadu.ca
# ['Foerster,', 'Andrew']
# Andrew Foerster afoerster@faculty.ocadu.ca
# ['Fofana,', 'Richard']
# Richard Fofana rfofana@faculty.ocadu.ca
# ['Fong,', 'Alexis']
# Alexis Fong afong@ocadu.ca
# ['Forni,', 'Silvia']
# Silvia Forni sforni@faculty.ocadu.ca
# ['Forrow,', 'Adrian']
# Adrian Forrow aforrow@faculty.ocadu.ca
# ['Forsyth,', 'Michelle']
# Michelle Forsyth mforsyth@faculty.ocadu.ca
# ['Fraser,', 'Peter']
# Peter Fraser pfraser@ocadu.ca
# ['Freeman,', 'Travis']
# Travis Freeman tfreeman@ocadu.ca
# ['Frisch,', 'Joanne']
# Joanne Frisch jfrisch@ocadu.ca
# ['Frise,', 'Heather']
# Heather Frise hfrise@faculty.ocadu.ca
# ['Gaby-Trotz,', 'Anna']
# Anna Gaby-Trotz agabytrotz@faculty.ocadu.ca
# ['Gaito,', 'Elaine']
# Elaine Gaito egaito@ocadu.ca
# ['Galindo,', 'Ana']
# Ana Galindo agalindo@faculty.ocadu.ca
# ['Garbett,', 'Mark']
# Mark Garbett mgarbett@faculty.ocadu.ca
# ['Garnet,', 'Eldon']
# Eldon Garnet egarnet@faculty.ocadu.ca
# ['Gault,', 'Joseph']
# Joseph Gault jgault@faculty.ocadu.ca
# ['Gaur,', 'Sugandha']
# Sugandha Gaur sgaur@faculty.ocadu.ca
# ['Gay,', 'Michelle']
# Michelle Gay mgay@faculty.ocadu.ca
# ['Gay,', 'Michelle']
# Michelle Gay mgay@faculty.ocadu.ca
# ['General,', 'Melissa']
# Melissa General mgeneral@ocadu.ca
# ['Geraghty,', 'Rhonda']
# Rhonda Geraghty rgeraghty@faculty.ocadu.ca
# ['Gerard,', 'Shannon']
# Shannon Gerard sgerard@faculty.ocadu.ca
# ['Gerry,', 'Howard']
# Howard Gerry hgerry@faculty.ocadu.ca
# ['Ghodke,', 'Uttara']
# Uttara Ghodke graduate@ocadsu.org
# ['Gibb,', 'Lindsay']
# Lindsay Gibb lgibb@ocadu.ca
# ['Giberson,', 'Kimberly']
# Kimberly Giberson kgiberson@ocadu.ca
# ['Gill,', 'Avtar']
# Avtar Gill agill@ocadu.ca
# ['Gillatly,', 'Courtney']
# Courtney Gillatly cgillatly@ocadu.ca
# ['Giraudy,', 'Cheryl']
# Cheryl Giraudy cgiraudy@faculty.ocadu.ca
# ['Girling,', 'Candida']
# Candida Girling cgirling@faculty.ocadu.ca
# ['Girling,', 'Candida']
# Candida Girling cgirling@faculty.ocadu.ca
# ['Givord,', 'Priam']
# Priam Givord pgivord@faculty.ocadu.ca
# ['Glass,', 'Simon']
# Simon Glass sglass@faculty.ocadu.ca
# ['Gnanasabesan,', 'Jenny']
# Jenny Gnanasabesan jgnanasabesan@ocadu.ca
# ['Godson,', 'Ellen']
# Ellen Godson egodson@faculty.ocadu.ca
# ['Golberg,', 'Melissa']
# Melissa Golberg mgolberg@ocadu.ca
# ['Goodall,', 'Derwyn']
# Derwyn Goodall dgoodall@faculty.ocadu.ca
# ['Gordon,', 'Marcus']
# Marcus Gordon mgordon@ocadu.ca
# ['Goso,', 'Nick']
# Nick Goso ngoso@faculty.ocadu.ca
# ['Goso,', 'Nick']
# Nick Goso ngoso@faculty.ocadu.ca
# ['Goss,', 'Jules']
# Jules Goss jgoss@faculty.ocadu.ca
# ['Graham,', 'Archie']
# Archie Graham agraham@faculty.ocadu.ca
# ['Graham,', 'Jonathan']
# Jonathan Graham jgraham@ocadu.ca
# ['Granados,', 'Francisco']
# Francisco Granados fgranados@faculty.ocadu.ca
# ['Grant,', 'Roderick']
# Roderick Grant rgrant@faculty.ocadu.ca
# ['Graziano,', 'Rosalinda']
# Rosalinda Graziano rgraziano@faculty.ocadu.ca
# ['Grezova,', 'Mariana']
# Mariana Grezova mgrezova@faculty.ocadu.ca
# ['Griffin,', 'David']
# David Griffin dgriffin@faculty.ocadu.ca
# ['Grison,', 'Gerald']
# Gerald Grison ggrison@ocadu.ca
# ['Grison,', 'Gerald']
# Gerald Grison ggrison@ocadu.ca
# ['Guarin,', 'Renzi']
# Renzi Guarin rguarin@ocadu.ca
# ['Gulamhusein,', 'Zul']
# Zul Gulamhusein zgulamhusein@ocadu.ca
# ['Hahn,', 'Frances']
# Frances Hahn fhahn@faculty.ocadu.ca
# ['Haladyn,', 'Julian']
# Julian Haladyn julianhaladyn@faculty.ocadu.ca
# ['Hallett,', 'Bryce']
# Bryce Hallett bhallett@faculty.ocadu.ca
# ['Hambleton,', 'Joseph']
# Joseph Hambleton josephhambleton@faculty.ocadu.ca
# ['Han,', 'Gloria']
# Gloria Han ghan@ocadu.ca
# ['Harland,', 'Daniel']
# Daniel Harland dharland@faculty.ocadu.ca
# ['Harnum,', 'Alan']
# Alan Harnum aharnum@ocadu.ca
# ['Harrison,', 'Spencer', 'J.']
# Spencer Harrison sharrison@faculty.ocadu.ca
# ['Hartman,', 'Kate']
# Kate Hartman khartman@faculty.ocadu.ca
# ['Hartman,', 'Kate']
# Kate Hartman khartman@faculty.ocadu.ca
# ['He,', 'Ling']
# Ling He lhe@ocadu.ca
# ['Henry,', 'Karen']
# Karen Henry khenry@ocadu.ca
# ['Henry,', 'Lisa']
# Lisa Henry lhenry@ocadu.ca
# ['Hewgill,', 'Jody']
# Jody Hewgill jhewgill@faculty.ocadu.ca
# ['Hickey,', 'Matthew']
# Matthew Hickey matthewhickey@faculty.ocadu.ca
# ['Hickox,', 'April']
# April Hickox ahickox@faculty.ocadu.ca
# ['Higuerey', 'Nunez,', 'Julian']
# Nunez, Higuere jhiguereynunez@ocadu.ca
# ['Hinds,', 'Bruce']
# Bruce Hinds bhinds@faculty.ocadu.ca
# ['Hladin,', 'Brian']
# Brian Hladin bhladin@faculty.ocadu.ca
# ['Ho,', 'Grace']
# Grace Ho gho@ocadu.ca
# ['Ho,', 'Victoria']
# Victoria Ho vho@ocadu.ca
# ['Hobbs,', 'Peter']
# Peter Hobbs phobbs@faculty.ocadu.ca
# ['Hoessler,', 'Carolyn']
# Carolyn Hoessler choessler@ocadu.ca
# ['Holmes,', 'Natasha']
# Natasha Holmes nholmes@ocadu.ca
# ['Homanchuk,', 'Alex']
# Alex Homanchuk ahomanchuk@ocadu.ca
# ['Hong,', 'Alexandra']
# Alexandra Hong ahong@ocadu.ca
# ['Hooper,', 'Nicholas']
# Nicholas Hooper nhooper@ocadu.ca
# ['Hope,', 'Melanie']
# Melanie Hope mhope@faculty.ocadu.ca
# ['Hopkins,', 'Candice']
# Candice Hopkins chopkins@faculty.ocadu.ca
# ['Hotrum,', 'Amanda']
# Amanda Hotrum ahotrum@ocadu.ca
# ['Householder,', 'Johanna']
# Johanna Householder jhouseholder@faculty.ocadu.ca
# ['Householder,', 'Johanna']
# Johanna Householder jhouseholder@faculty.ocadu.ca
# ['Huang,', 'Christina']
# Christina Huang chuang@ocadu.ca
# ['Huang,', 'Weifang']
# Weifang Huang whuang@ocadu.ca
# ['Hudson,', 'Audrey']
# Audrey Hudson ahudson@faculty.ocadu.ca
# ['Huggett,', 'Katrina']
# Katrina Huggett khuggett@ocadu.ca
# ['Hughes,', 'Dafydd']
# Dafydd Hughes dafyddhughes@faculty.ocadu.ca
# ['Hung,', 'Jonathan']
# Jonathan Hung jhung@ocadu.ca
# ['Hunniford,', 'Andrea']
# Andrea Hunniford ahunniford@ocadu.ca
# ['Hunt,', 'Richard']
# Richard Hunt rhunt@faculty.ocadu.ca
# ['Husain,', 'Oliver']
# Oliver Husain ohusain@faculty.ocadu.ca
# ['Hussain,', 'Shazia']
# Shazia Hussain shussain@ocadu.ca
# ['Hutchinson,', 'Daniel']
# Daniel Hutchinson dhutchinson@faculty.ocadu.ca
# ['Iles,', 'Gillian']
# Gillian Iles giles@faculty.ocadu.ca
# ['Ing,', 'Garry']
# Garry Ing ging@faculty.ocadu.ca
# ['Irizawa,', 'Jay']
# Jay Irizawa jirizawa@faculty.ocadu.ca
# ['Isaacs,', 'Camille']
# Camille Isaacs cisaacs@faculty.ocadu.ca
# ['Iskander,', 'Martin']
# Martin Iskander miskander@ocadu.ca
# ['Italiano,', 'Victoria']
# Victoria Italiano vitaliano@ocadu.ca
# ['Jackson,', 'Paul']
# Paul Jackson pjackson@ocadu.ca
# ['Jagassar,', 'Kristina']
# Kristina Jagassar kjagassar@ocadu.ca
# ['Jain,', 'Nancy']
# Nancy Jain njain@faculty.ocadu.ca
# ['James,', 'Brent']
# Brent James bjames@ocadu.ca
# ['James,', 'Charlene']
# Charlene James cjames@ocadu.ca
# ['Janzen,', 'Sandra']
# Sandra Janzen sjanzen@ocadu.ca
# ['Jaroszewicz,', 'Mark']
# Mark Jaroszewicz mjaroszewicz@faculty.ocadu.ca
# ['Jarvis,', 'Bentley']
# Bentley Jarvis bjarvis@faculty.ocadu.ca
# ['Jarvis,', 'Carlos']
# Carlos Jarvis cjarvis@faculty.ocadu.ca
# ['Jarvis,', 'Ian']
# Ian Jarvis ijarvis@faculty.ocadu.ca
# ['Jelsma,', 'Michelle']
# Michelle Jelsma mjelsma@ocadu.ca
# ['Jeyarajah,', 'Christine']
# Christine Jeyarajah cjeyarajah@ocadu.ca
# ['Ji,', 'Haru']
# Haru Ji hji@faculty.ocadu.ca
# ['Jno', 'Baptiste,', 'Laurelle']
# Baptiste, Jn ljnobaptiste@ocadu.ca
# ['Joe,', 'Brian']
# Brian Joe bjoe@ocadu.ca
# ['Johnson,', 'Lillianne']
# Lillianne Johnson ljohnson@ocadu.ca
# ['Johnson,', 'Rae']
# Rae Johnson rjohnson@faculty.ocadu.ca
# ['Jones,', 'Karson']
# Karson Jones karsonjones@ocadu.ca
# ['Jones,', 'Kip']
# Kip Jones kjones@faculty.ocadu.ca
# ['Jones,', 'Lee']
# Lee Jones ljones@ocadu.ca
# ['Jones,', 'Peter']
# Peter Jones pjones@faculty.ocadu.ca
# ['Jones,', 'Simone']
# Simone Jones sjones@faculty.ocadu.ca
# ['Joseph,', 'Kirstie']
# Kirstie Joseph kjoseph@ocadu.ca
# ['Joshi,', 'Ajay']
# Ajay Joshi ajoshi@ocadu.ca
# ['Judd,', 'Alison']
# Alison Judd ajudd@faculty.ocadu.ca
# ['Julien,', 'Mark']
# Mark Julien mjulien@ocadu.ca
# ['Jung,', 'Amy']
# Amy Jung ajung@ocadu.ca
# ['Justl,', 'Karen']
# Karen Justl kjustl@faculty.ocadu.ca
# ['Kaplan,', 'Ruth']
# Ruth Kaplan rkaplan@faculty.ocadu.ca
# ['Kara,', 'Selmin']
# Selmin Kara skara@faculty.ocadu.ca
# ['Karuhanga,', 'Jessica']
# Jessica Karuhanga jkaruhanga@faculty.ocadu.ca
# ['Kedey,', 'Sandra']
# Sandra Kedey skedey@faculty.ocadu.ca
# ['Keller,', 'Miles']
# Miles Keller mkeller@faculty.ocadu.ca
# ['Kelly,', 'Brennan']
# Brennan Kelly brennankelly@faculty.ocadu.ca
# ['Kelly,', 'Donald']
# Donald Kelly dkelly@ocadu.ca
# ['Kelly,', 'Nathan']
# Nathan Kelly nkelly@ocadu.ca
# ['Kemp,', 'Susan']
# Susan Kemp skemp@ocadu.ca
# ['Kennedy,', 'Tredegar']
# Tredegar Kennedy tkennedy@faculty.ocadu.ca
# ['Kerr,', 'Anthony']
# Anthony Kerr tkerr@faculty.ocadu.ca
# ['Kerr,', 'Helen']
# Helen Kerr hkerr@faculty.ocadu.ca
# ['Kerr,', 'Randy']
# Randy Kerr rkerr@faculty.ocadu.ca
# ['Khokher,', 'Reginald']
# Reginald Khokher rkhokher@faculty.ocadu.ca
# ['Kiloh,', 'Katherine']
# Katherine Kiloh kkiloh@faculty.ocadu.ca
# ['Kim,', 'Chris']
# Chris Kim chriskim@faculty.ocadu.ca
# ['Kim,', 'Chung-Im']
# Chung-Im Kim ckim@faculty.ocadu.ca
# ['Kinsley,', 'Alex']
# Alex Kinsley akinsley@faculty.ocadu.ca
# ['Klaehn,', 'Nathan']
# Nathan Klaehn nklaehn@ocadu.ca
# ['Knaff,', 'Jean-Christian']
# Jean-Christian Knaff jknaff@faculty.ocadu.ca
# ['Komguem,', 'Leonce']
# Leonce Komguem lkomguem@faculty.ocadu.ca
# ['Kostoff,', 'Larissa']
# Larissa Kostoff lkostoff@ocadu.ca
# ['Kramer,', 'Miriam']
# Miriam Kramer mkramer@ocadu.ca
# ['Krause,', 'Adam']
# Adam Krause akrause@ocadu.ca
# ['Krzyzanowski,', 'Stan']
# Stan Krzyzanowski skrzyzanowski@faculty.ocadu.ca
# ['Kubis,', 'Anda']
# Anda Kubis akubis@faculty.ocadu.ca
# ['Kubis,', 'Anda']
# Anda Kubis akubis@faculty.ocadu.ca
# ['Kumar,', 'Kunnal']
# Kunnal Kumar kkumar@ocadu.ca
# ['Kumar,', 'Rachna']
# Rachna Kumar rkumar@ocadu.ca
# ['Kushnir,', 'Helena']
# Helena Kushnir lkushnir@faculty.ocadu.ca
# ['Kuzma,', 'Chris']
# Chris Kuzma ckuzma@faculty.ocadu.ca
# ['Kwasnicki,', 'Matthew']
# Matthew Kwasnicki mkwasnicki@ocadu.ca
# ['Kwon,', 'Karen']
# Karen Kwon kkwon@ocadu.ca
# ['Kyle,', 'Patrick']
# Patrick Kyle pkyle@faculty.ocadu.ca
# ['Ladly,', 'Martha']
# Martha Ladly mladly@faculty.ocadu.ca
# ['Ladly,', 'Martha']
# Martha Ladly mladly@faculty.ocadu.ca
# ['Laliberte,', 'Colette']
# Colette Laliberte claliberte@faculty.ocadu.ca
# ['Lamont,', 'Sylvie']
# Sylvie Lamont slamont@faculty.ocadu.ca
# ['Landry,', 'Chris']
# Chris Landry clandry@ocadu.ca
# ['Lane,', 'Andrew']
# Andrew Lane alane@faculty.ocadu.ca
# ['Lange,', 'Chris']
# Chris Lange chrislange@faculty.ocadu.ca
# ['Langill,', 'Caroline']
# Caroline Langill clangill@ocadu.ca
# ['Langille,', 'Reid']
# Reid Langille rlangille@faculty.ocadu.ca
# ['Langis,', 'Hugh']
# Hugh Langis hlangis@faculty.ocadu.ca
# ['Lansdowne,', 'Tristram']
# Tristram Lansdowne tlansdowne@faculty.ocadu.ca
# ['Lauder,', 'Adam']
# Adam Lauder alauder@faculty.ocadu.ca
# ['LaVallee,', 'Melissa']
# Melissa LaVallee mlavallee@ocadu.ca
# ['Lawoti,', 'Surendra']
# Surendra Lawoti slawoti@faculty.ocadu.ca
# ['Lawrason,', 'June']
# June Lawrason jlawrason@faculty.ocadu.ca
# ['Leacock,', 'Nakia']
# Nakia Leacock nleacock@ocadu.ca
# ['Lear,', 'Robert']
# Robert Lear rlear@faculty.ocadu.ca
# ['Lebouthillier,', 'Francis']
# Francis Lebouthillier flebouthillier@faculty.ocadu.ca
# ['Lee,', 'Darren']
# Darren Lee darrenlee@faculty.ocadu.ca
# ['Lee,', 'JJ']
# JJ Lee jlee@faculty.ocadu.ca
# ['Lee,', 'Min', 'Sook']
# Min Lee minsooklee@faculty.ocadu.ca
# ['Lee,', 'Ranee']
# Ranee Lee rlee@faculty.ocadu.ca
# ['Lee,', 'Serena']
# Serena Lee slee@ocadu.ca
# ['Lee,', 'Teresa']
# Teresa Lee tlee@faculty.ocadu.ca
# ['Lee,', 'Teresa']
# Teresa Lee tlee@faculty.ocadu.ca
# ['Lee', 'Leitch,', 'Mary', 'Ann']
# Leitch, Le mlee@ocadu.ca
# ['Lee-Kim,', 'Daniela']
# Daniela Lee-Kim dleekim@ocadu.ca
# ['Leeming,', 'Bill']
# Bill Leeming bleeming@faculty.ocadu.ca
# ['Leenhouts,', 'Simon']
# Simon Leenhouts sleenhouts@ocadu.ca
# ['Legare,', 'Ginette']
# Ginette Legare glegare@faculty.ocadu.ca
# ['Leggett,', 'Samantha']
# Samantha Leggett sleggett@ocadu.ca
# ['Leitao,', 'Renata']
# Renata Leitao rleitao@ocadu.ca
# ['Leitch,', 'Alex']
# Alex Leitch aleitch@faculty.ocadu.ca
# ['Leitch,', 'Alex']
# Alex Leitch aleitch@faculty.ocadu.ca
# ['Leo,', 'Nina']
# Nina Leo nleo@faculty.ocadu.ca
# ['Lessio,', 'Nadine']
# Nadine Lessio nlessio@faculty.ocadu.ca
# ['Li,', 'Cheryl']
# Cheryl Li cheryl.li@ocadu.ca
# ['Li,', 'Cindy']
# Cindy Li cli@ocadu.ca
# ['Liaw,', 'Anson']
# Anson Liaw aliaw@faculty.ocadu.ca
# ['Liddington,', 'Derek']
# Derek Liddington dliddington@faculty.ocadu.ca
# ['Liefhebber,', 'Martin']
# Martin Liefhebber mliefhebber@faculty.ocadu.ca
# ['Limeback,', 'Kurt']
# Kurt Limeback klimeback@faculty.ocadu.ca
# ['Lincez,', 'Mathew']
# Mathew Lincez mlincez@faculty.ocadu.ca
# ['Lindo,', 'Sabrina']
# Sabrina Lindo slindo@ocadu.ca
# ['Linton,', 'Jennifer']
# Jennifer Linton jlinton@faculty.ocadu.ca
# ['Linton,', 'Jennifer']
# Jennifer Linton jlinton@faculty.ocadu.ca
# ['Liskovoi,', 'Lisa']
# Lisa Liskovoi lliskovoi@ocadu.ca
# ['Lo,', 'Christian']
# Christian Lo clo@faculty.ocadu.ca
# ['Lo,', 'Lorna']
# Lorna Lo llo@ocadu.ca
# ['Lovas,', 'Mike']
# Mike Lovas mlovas@faculty.ocadu.ca
# ['Lovell-Anderson,', 'Laura']
# Laura Lovell-Anderson llovellanderson@faculty.ocadu.ca
# ['Lowry,', 'Glen']
# Glen Lowry glowry@ocadu.ca
# ['Luca,', 'Bogdan']
# Bogdan Luca bluca@faculty.ocadu.ca
# ['Ludwig,', 'Gary']
# Gary Ludwig gludwig@faculty.ocadu.ca
# ['Luke,', 'Robert']
# Robert Luke rluke@ocadu.ca
# ['Ly,', 'Cindy']
# Cindy Ly cindyly@ocadu.ca
# ['Maas,', 'Tori']
# Tori Maas tmaas@ocadu.ca
# ['Mac,', 'Jessica']
# Jessica Mac jmac@ocadu.ca
# ['Macalik,', 'Jana']
# Jana Macalik jmacalik@ocadu.ca
# ['Macalik,', 'Jana']
# Jana Macalik jmacalik@ocadu.ca
# ['MacDonald,', 'Arin']
# Arin MacDonald arinmacdonald@ocadu.ca
# ['MacDonald,', 'Lindsay']
# Lindsay MacDonald lindsaymacdonald@faculty.ocadu.ca
# ['MacDonald,', 'Lisa']
# Lisa MacDonald lmacdonald@ocadu.ca
# ['Mace,', 'Jessica']
# Jessica Mace jmace@faculty.ocadu.ca
# ['MacGregor,', 'Gwen']
# Gwen MacGregor gmacgregor@faculty.ocadu.ca
# ['Mach,', 'Erica']
# Erica Mach emach@ocadu.ca
# ['MacHenry,', 'Rachel']
# Rachel MacHenry rmachenry@faculty.ocadu.ca
# ['MacLeod,', 'Alastair']
# Alastair MacLeod amacleod@ocadu.ca
# ['Madden,', 'Tamela']
# Tamela Madden tmadden@ocadu.ca
# ['Magsalay,', 'Christine']
# Christine Magsalay cmagsalay@ocadu.ca
# ['Mahler,', 'Harry']
# Harry Mahler hmahler@faculty.ocadu.ca
# ['Mahvash,', 'Kourosh']
# Kourosh Mahvash kmahvash@faculty.ocadu.ca
# ['Mandoda,', 'Minesh']
# Minesh Mandoda mmandoda@ocadu.ca
# ['Mansur,', 'Omita']
# Omita Mansur omansur@ocadu.ca
# ['Mantzanis,', 'Nicolas']
# Nicolas Mantzanis nmantzanis@faculty.ocadu.ca
# ['Manu,', 'Alexander']
# Alexander Manu amanu@faculty.ocadu.ca
# ['Maraston,', 'Liz']
# Liz Maraston lmaraston@ocadu.ca
# ['Marino,', 'Daniela']
# Daniela Marino dmarino@faculty.ocadu.ca
# ['Marocco,', 'Gino']
# Gino Marocco campaigns@ocadsu.org
# ['Martin,', 'Hugh']
# Hugh Martin hmartin@faculty.ocadu.ca
# ['Martinello,', 'Linda']
# Linda Martinello lmartinello@faculty.ocadu.ca
# ['Martinez,', 'Isabel']
# Isabel Martinez imartinez@ocadu.ca
# ['Mastroeni,', 'Michele']
# Michele Mastroeni mmastroeni@faculty.ocadu.ca
# ['Mastroeni,', 'Michele']
# Michele Mastroeni mmastroeni@faculty.ocadu.ca
# ['Mathur,', 'Ashok']
# Ashok Mathur amathur@ocadu.ca
# ['Mavis,', 'Morgan']
# Morgan Mavis mmavis@ocadu.ca
# ['Mawani,', 'Alim']
# Alim Mawani amawani@ocadu.ca
# ['Maxwell,', 'James']
# James Maxwell jmaxwell@faculty.ocadu.ca
# ['Maxwell,', 'James']
# James Maxwell jmaxwell@faculty.ocadu.ca
# ['May,', 'Chris']
# Chris May cmay@faculty.ocadu.ca
# ['McAllister,', 'Andrew']
# Andrew McAllister amcallister@ocadu.ca
# ['McConnell,', 'Jackson']
# Jackson McConnell jmcconnell@faculty.ocadu.ca
# ['McCrum,', 'Guy']
# Guy McCrum gmccrum@faculty.ocadu.ca
# ['McGlade,', 'Christine']
# Christine McGlade cmcglade@faculty.ocadu.ca
# ['McIntosh,', 'David']
# David McIntosh dmcintosh@faculty.ocadu.ca
# ['McKay,', 'Robert']
# Robert McKay rmckay@ocadu.ca
# ['McKenzie,', 'Van']
# Van McKenzie vmckenzie@faculty.ocadu.ca
# ['McLaren,', 'Alexandra']
# Alexandra McLaren amclaren@ocadu.ca
# ['McLaren,', 'Nadia']
# Nadia McLaren nmclaren@ocadu.ca
# ['McMaster,', 'Gerald']
# Gerald McMaster gmcmaster@faculty.ocadu.ca
# ['McOuat,', 'Karen']
# Karen McOuat kmcouat@ocadu.ca
# ['McRoberts,', 'Greg']
# Greg McRoberts gmcroberts@faculty.ocadu.ca
# ['Meachen,', 'David']
# David Meachen dmeachen@ocadu.ca
# ['Mead,', 'Wrik']
# Wrik Mead wmead@faculty.ocadu.ca
# ['Meirelles,', 'Isabel']
# Isabel Meirelles imeirelles@faculty.ocadu.ca
# ['Men,', 'Immony']
# Immony Men imen@faculty.ocadu.ca
# ['Mendes,', 'Rhys']
# Rhys Mendes rmendes@faculty.ocadu.ca
# ['Mhakayakora,', 'Zvikomborero']
# Zvikomborero Mhakayakora zmhakayakora@faculty.ocadu.ca
# ['Michail,', 'Angie']
# Angie Michail amichail@faculty.ocadu.ca
# ['Mikhael,', 'Diane']
# Diane Mikhael dmikhael@faculty.ocadu.ca
# ['Milgram,', 'Lynne']
# Lynne Milgram lmilgram@faculty.ocadu.ca
# ['Milic,', 'Dushan']
# Dushan Milic dmilic@faculty.ocadu.ca
# ['Millard,', 'Laura']
# Laura Millard lmillard@faculty.ocadu.ca
# ['Miller,', 'James']
# James Miller jamesmiller@faculty.ocadu.ca
# ['Miller,', 'Michael']
# Michael Miller mmiller@faculty.ocadu.ca
# ['Miller,', 'Michelle']
# Michelle Miller michellemiller@faculty.ocadu.ca
# ['Millerson,', 'Dorothy']
# Dorothy Millerson dmillerson@faculty.ocadu.ca
# ['Millerson,', 'Dorothy']
# Dorothy Millerson dmillerson@faculty.ocadu.ca
# ['Miner,', 'Colin']
# Colin Miner cminer@faculty.ocadu.ca
# ['Mirlin,', 'Ian']
# Ian Mirlin imirlin@faculty.ocadu.ca
# ['Mishchenko,', 'Olia']
# Olia Mishchenko omishchenko@faculty.ocadu.ca
# ['Mitchell,', 'Jess']
# Jess Mitchell jmitchell@ocadu.ca
# ['Mitchell,', 'Robert']
# Robert Mitchell rmitchell@faculty.ocadu.ca
# ['Moffet,', 'Joel']
# Joel Moffet jmoffet@faculty.ocadu.ca
# ['Moffet,', 'Joel']
# Joel Moffet jmoffet@faculty.ocadu.ca
# ['Mok,', 'Heidi']
# Heidi Mok hmok@faculty.ocadu.ca
# ['Mondesir,', 'Esery']
# Esery Mondesir emondesir@faculty.ocadu.ca
# ['Moore,', 'Kirstyn']
# Kirstyn Moore kmoore@ocadu.ca
# ['Moore,', 'Laura']
# Laura Moore lmoore@faculty.ocadu.ca
# ['Moore,', 'Ryan']
# Ryan Moore rmoore@ocadu.ca
# ['Moorehead,', 'Christopher']
# Christopher Moorehead cmoorehead@faculty.ocadu.ca
# ['Moorehead,', 'Christopher']
# Christopher Moorehead cmoorehead@faculty.ocadu.ca
# ['Morgado,', 'Silvia']
# Silvia Morgado smorgado@ocadu.ca
# ['Morin,', 'Peter']
# Peter Morin pmorin@faculty.ocadu.ca
# ['Moriyama,', 'Joni']
# Joni Moriyama jmoriyama@faculty.ocadu.ca
# ['Morrell,', 'Amish']
# Amish Morrell amorrell@faculty.ocadu.ca
# ['Morris,', 'Alexis']
# Alexis Morris amorris@faculty.ocadu.ca
# ['Morris,', 'Kathleen']
# Kathleen Morris kmorris@faculty.ocadu.ca
# ['Morris,', 'Kevin']
# Kevin Morris kevinmorris@ocadu.ca
# ['Morrissette,', 'Suzanne']
# Suzanne Morrissette smorrissette@faculty.ocadu.ca
# ['Morrow,', 'James']
# James Morrow jmorrow@ocadu.ca
# ['Moser,', 'Gabrielle']
# Gabrielle Moser gmoser@faculty.ocadu.ca
# ['Moss,', 'Gregor']
# Gregor Moss gmoss@ocadu.ca
# ['Moss,', 'Zachary']
# Zachary Moss zmoss@ocadu.ca
# ['Mozzone,', 'Frank']
# Frank Mozzone fmozzone@ocadu.ca
# ['Mulholland,', 'Sarah']
# Sarah Mulholland smulholland@ocadu.ca
# ['Mullin,', 'Derek']
# Derek Mullin dmullin@faculty.ocadu.ca
# ['Munroe,', 'Howard']
# Howard Munroe hmunroe@faculty.ocadu.ca
# ['Mwesigwa,', 'Wycliff']
# Wycliff Mwesigwa wmwesigwa@ocadu.ca
# ['Nanton,', 'Natalie']
# Natalie Nanton nnanton@ocadu.ca
# ['Navarro,', 'Patrick']
# Patrick Navarro pnavarro@ocadu.ca
# ['Nay,', 'Eric']
# Eric Nay enay@faculty.ocadu.ca
# ['Neher,', 'Iris']
# Iris Neher ineher@ocadu.ca
# ['Nejadriahi,', 'Halleh']
# Halleh Nejadriahi hnejadriahi@faculty.ocadu.ca
# ['Neuspiel,', 'Tibi']
# Tibi Neuspiel tneuspiel@ocadu.ca
# ['Newing,', 'Gillian']
# Gillian Newing gnewing@faculty.ocadu.ca
# ['Newman,', 'Gary']
# Gary Newman gnewman@ocadu.ca
# ['Ng-Klee,', 'Yinnie']
# Yinnie Ng-Klee yngklee@ocadu.ca
# ['Nicholls,', 'Alison']
# Alison Nicholls anicholls@ocadu.ca
# ['Nicholls,', 'Rob']
# Rob Nicholls rnicholls@faculty.ocadu.ca
# ['Nicholson,', 'Lewis']
# Lewis Nicholson lnicholson@faculty.ocadu.ca
# ['Nicoll,', 'Gayle']
# Gayle Nicoll gnicoll@faculty.ocadu.ca
# ['Nielsen,', 'Tannis']
# Tannis Nielsen tnielsen@faculty.ocadu.ca
# ['Nigam,', 'Arpit']
# Arpit Nigam anigam@ocadu.ca
# ['Nikolic,', 'Nikola']
# Nikola Nikolic nnikolic@ocadu.ca
# ['Nimkulrat,', 'Nithikul']
# Nithikul Nimkulrat nnimkulrat@faculty.ocadu.ca
# ['Nind,', 'Sarah']
# Sarah Nind snind@faculty.ocadu.ca
# ['Nishimura,', 'Emma']
# Emma Nishimura enishimura@faculty.ocadu.ca
# ['Nishimura,', 'Emma']
# Emma Nishimura enishimura@faculty.ocadu.ca
# ['Nkosi,', 'Mbuso']
# Mbuso Nkosi No Email
# ['Noble,', 'Crawford']
# Crawford Noble cnoble@faculty.ocadu.ca
# ['Noor,', 'Tamara']
# Tamara Noor tnoor@ocadu.ca
# ['Norman,', 'Cameron']
# Cameron Norman cnorman@faculty.ocadu.ca
# ['Norman,', 'Jennifer']
# Jennifer Norman jnorman@faculty.ocadu.ca
# ['Norman,', 'Richard']
# Richard Norman rnorman@faculty.ocadu.ca
# ['Northway-Frank,', 'Jason']
# Jason Northway-Frank jnorthwayfrank@ocadu.ca
# ['Noussis,', 'Angela']
# Angela Noussis anoussis@faculty.ocadu.ca
# ['Nurse,', 'Lauren']
# Lauren Nurse laurennurse@faculty.ocadu.ca
# ["O'Neill,", 'Braden']
# Braden O'Neill boneill@faculty.ocadu.ca
# ['Obara,', 'Justin']
# Justin Obara jobara@ocadu.ca
# ['Obas,', 'Jordan']
# Jordan Obas jobas@ocadu.ca
# ['Oikonen,', 'Karen']
# Karen Oikonen karenoikonen@faculty.ocadu.ca
# ['Oliveira,', 'Susy']
# Susy Oliveira soliveira@faculty.ocadu.ca
# ['Olley,', 'James']
# James Olley jolley@faculty.ocadu.ca
# ['Ordonez,', 'Cristian']
# Cristian Ordonez cordonez@faculty.ocadu.ca
# ['Ordonez,', 'Maria']
# Maria Ordonez mordonez@faculty.ocadu.ca
# ['Osenton,', 'Sara']
# Sara Osenton sosenton@ocadu.ca
# ['Ostoff,', 'Nicholas']
# Nicholas Ostoff nostoff@faculty.ocadu.ca
# ['Otterson,', 'David']
# David Otterson dotterson@faculty.ocadu.ca
# ['Padamshi,', 'Kais']
# Kais Padamshi academic@ocadsu.org
# ['Page,', 'Michael']
# Michael Page mpage@faculty.ocadu.ca
# ['Paglione,', 'Joshua']
# Joshua Paglione jpaglione@ocadu.ca
# ['Painter,', 'Luke']
# Luke Painter lpainter@faculty.ocadu.ca
# ['Pak,', 'June']
# June Pak jpak@faculty.ocadu.ca
# ['Panagiotakopoulos,', 'Panagiotis']
# Panagiotis Panagiotakopoulos ppanagiotakopoulos@faculty.ocadu.ca
# ['Panton,', 'Doug']
# Doug Panton dpanton@faculty.ocadu.ca
# ['Pape,', 'Michael']
# Michael Pape mpape@faculty.ocadu.ca
# ['Paradis,', 'Elisabeth']
# Elisabeth Paradis eparadis@ocadu.ca
# ['Park,', 'Soyang']
# Soyang Park spark@faculty.ocadu.ca
# ['Parle,', 'Kathleen']
# Kathleen Parle kparle@faculty.ocadu.ca
# ['Parnell,', 'Luke']
# Luke Parnell lparnell@faculty.ocadu.ca
# ['Patrick,', 'Jill']
# Jill Patrick jpatrick@ocadu.ca
# ['Patterson,', 'Pam']
# Pam Patterson ppatterson@faculty.ocadu.ca
# ['Patton,', 'Andrew']
# Andrew Patton apatton@faculty.ocadu.ca
# ['Pavilionis,', 'Ramona']
# Ramona Pavilionis ramonapavilionis@faculty.ocadu.ca
# ['Pavlenko,', 'Natalie']
# Natalie Pavlenko npavlenko@ocadu.ca
# ['Pavlovic,', 'Milan']
# Milan Pavlovic mpavlovic@faculty.ocadu.ca
# ['Payne,', 'Daniel']
# Daniel Payne dpayne@ocadu.ca
# ['Pearl,', 'David']
# David Pearl dpearl@faculty.ocadu.ca
# ['Pearl,', 'Zachary']
# Zachary Pearl zpearl@faculty.ocadu.ca
# ['Pelechaty,', 'Jenna']
# Jenna Pelechaty jpelechaty@ocadu.ca
# ['Penny,', 'Laura']
# Laura Penny lpenny@ocadu.ca
# ['Pereyra,', 'David']
# David Pereyra dpereyra@ocadu.ca
# ['Perrin,', 'Janice']
# Janice Perrin jperrin@ocadu.ca
# ['Peteran,', 'Gordon']
# Gordon Peteran gpeteran@faculty.ocadu.ca
# ['Petkovic,', 'Tatjana']
# Tatjana Petkovic tpetkovic@faculty.ocadu.ca
# ['Peto,', 'Ben']
# Ben Peto bpeto@ocadu.ca
# ['Petrenko,', 'Anton']
# Anton Petrenko apetrenko@faculty.ocadu.ca
# ['Pham,', 'MyLy']
# MyLy Pham mpham@ocadu.ca
# ['Philipsz,', 'Christian']
# Christian Philipsz cphilipsz@ocadu.ca
# ['Phillips,', 'Gregory']
# Gregory Phillips gphillips@faculty.ocadu.ca
# ['Phillips,', 'Paulette']
# Paulette Phillips pphillips@faculty.ocadu.ca
# ['Pineda,', 'Christine']
# Christine Pineda cpineda@ocadu.ca
# ['Pineiro,', 'Ana']
# Ana Pineiro apineiro@ocadu.ca
# ['Pisano-Thomsen,', 'Robert']
# Robert Pisano-Thomsen rpisano@ocadu.ca
# ['Plavsa,', 'Manda']
# Manda Plavsa mplavsa@ocadu.ca
# ['Plavsa,', 'Stevan']
# Stevan Plavsa splavsa@ocadu.ca
# ['Ponesse,', 'Greg']
# Greg Ponesse gponesse@ocadu.ca
# ['Popiel,', 'Magdalena']
# Magdalena Popiel mpopiel@ocadu.ca
# ['Poremba,', 'Cindy']
# Cindy Poremba cporemba@faculty.ocadu.ca
# ['Porter,', 'Craig']
# Craig Porter cporter@ocadu.ca
# ['Porter,', 'Mary']
# Mary Porter mporter@faculty.ocadu.ca
# ['Power,', 'Stephanie']
# Stephanie Power spower@faculty.ocadu.ca
# ['Prabhu,', 'Neal']
# Neal Prabhu nprabhu@faculty.ocadu.ca
# ['Price,', 'Meghan']
# Meghan Price mprice@faculty.ocadu.ca
# ['Pridham,', 'Hudson']
# Hudson Pridham hpridham@faculty.ocadu.ca
# ['Prokopow,', 'Michael']
# Michael Prokopow mprokopow@faculty.ocadu.ca
# ['Puckett,', 'Nicholas']
# Nicholas Puckett npuckett@faculty.ocadu.ca
# ['Puckett,', 'Nicholas']
# Nicholas Puckett npuckett@faculty.ocadu.ca
# ['Pugen,', 'Diane']
# Diane Pugen dpugen@faculty.ocadu.ca
# ['Pye,', 'Nicholas']
# Nicholas Pye npye@faculty.ocadu.ca
# ['Qadeer,', 'Ali']
# Ali Qadeer aqadeer@faculty.ocadu.ca
# ['Qiu,', 'Annie']
# Annie Qiu aqiu@ocadu.ca
# ['Quan,', 'David']
# David Quan dquan@faculty.ocadu.ca
# ['Quinlan,', 'Steve']
# Steve Quinlan squinlan@faculty.ocadu.ca
# ['Quirt,', 'Melvin']
# Melvin Quirt mquirt@faculty.ocadu.ca
# ['Rabyniuk,', 'Simon']
# Simon Rabyniuk srabyniuk@faculty.ocadu.ca
# ['Rachid,', 'Nabil']
# Nabil Rachid nrachid@faculty.ocadu.ca
# ['Racho,', 'Mel']
# Mel Racho mracho@ocadu.ca
# ['Raghunath,', 'Nicholas']
# Nicholas Raghunath nraghunath@ocadu.ca
# ['Railton,', 'Echo']
# Echo Railton erailton@faculty.ocadu.ca
# ['Rampen,', 'Dick']
# Dick Rampen erampen@faculty.ocadu.ca
# ['Rauch,', 'Barbara']
# Barbara Rauch brauch@faculty.ocadu.ca
# ['Reeve,', 'Charles']
# Charles Reeve creeve@faculty.ocadu.ca
# ['Reichenbacher,', 'Helmut']
# Helmut Reichenbacher hreichenbacher@faculty.ocadu.ca
# ['Reid,', 'Colleen']
# Colleen Reid cmreid@faculty.ocadu.ca
# ['Reid,', 'Connie']
# Connie Reid conniereid@ocadu.ca
# ['Reid,', 'Lauchlan']
# Lauchlan Reid lreid@faculty.ocadu.ca
# ['Reid,', 'Stuart']
# Stuart Reid sreid@faculty.ocadu.ca
# ['Ren,', 'Hui']
# Hui Ren hren@ocadu.ca
# ['Reynolds,', 'Adrienne']
# Adrienne Reynolds areynolds@ocadu.ca
# ['Rice,', 'Ryan']
# Ryan Rice rrice@faculty.ocadu.ca
# ['Richards,', 'Lenore']
# Lenore Richards lrichards@ocadu.ca
# ['Richardson,', 'David']
# David Richardson drichardson@ocadu.ca
# ['Riva,', 'Lori']
# Lori Riva lriva@faculty.ocadu.ca
# ['Rivers,', 'Benjamin']
# Benjamin Rivers brivers@faculty.ocadu.ca
# ['Roberts,', 'Vera']
# Vera Roberts vroberts@ocadu.ca
# ['Roberts,', 'Vera']
# Vera Roberts vroberts@ocadu.ca
# ['Robinson,', 'Jennifer']
# Jennifer Robinson jrobinson@ocadu.ca
# ['Robson,', 'Heather']
# Heather Robson hrobson@ocadu.ca
# ['Roseborough,', 'James']
# James Roseborough jroseborough@ocadu.ca
# ['Ross,', 'Sam']
# Sam Ross sross@ocadu.ca
# ['Rossi,', 'Daniel']
# Daniel Rossi drossi@faculty.ocadu.ca
# ['Roushan,', 'Ala']
# Ala Roushan aroushan@faculty.ocadu.ca
# ['Rubino,', 'John']
# John Rubino jrubino@ocadu.ca
# ['Rucklidge,', 'Andrew']
# Andrew Rucklidge arucklidge@faculty.ocadu.ca
# ['Rushton,', 'Keith']
# Keith Rushton krushton@faculty.ocadu.ca
# ['Rutgers,', 'Job']
# Job Rutgers jrutgers@faculty.ocadu.ca
# ['Ruthralingam,', 'Moira']
# Moira Ruthralingam mruthralingam@ocadu.ca
# ['Sadieh,', 'Elnaz']
# Elnaz Sadieh esadieh@ocadu.ca
# ['Salih,', 'Honeida']
# Honeida Salih hsalih@ocadu.ca
# ['Samuel,', 'Clare']
# Clare Samuel csamuel@faculty.ocadu.ca
# ['Scheuhammer,', 'Joseph']
# Joseph Scheuhammer jscheuhammer@ocadu.ca
# ['Schneider,', 'Kate']
# Kate Schneider kschneider@faculty.ocadu.ca
# ['Schneider,', 'Kate']
# Kate Schneider kschneider@faculty.ocadu.ca
# ['Scilipoti,', 'Justine']
# Justine Scilipoti jscilipoti@ocadu.ca
# ['Scott,', 'Sabrina']
# Sabrina Scott sscott@faculty.ocadu.ca
# ['Scott,', 'Walter']
# Walter Scott wscott@faculty.ocadu.ca
# ['Seaforth,', 'Leslie']
# Leslie Seaforth lseaforth@ocadu.ca
# ['Seeschaaf-Veres,', 'Angelika']
# Angelika Seeschaaf-Veres aseeschaafveres@faculty.ocadu.ca
# ['Seeschaaf-Veres,', 'Angelika']
# Angelika Seeschaaf-Veres aseeschaafveres@faculty.ocadu.ca
# ['Sellen,', 'Kate']
# Kate Sellen ksellen@faculty.ocadu.ca
# ['Sevalrud,', 'Thomas']
# Thomas Sevalrud tsevalrud@faculty.ocadu.ca
# ['Shah,', 'Farihah']
# Farihah Shah fshah@faculty.ocadu.ca
# ['Shahi,', 'Sepideh']
# Sepideh Shahi sshahi@ocadu.ca
# ['Shaimanova,', 'Kira']
# Kira Shaimanova kshaimanova@faculty.ocadu.ca
# ['Shaw,', 'Robyn']
# Robyn Shaw rshaw@ocadu.ca
# ['Shea,', 'Geoffrey']
# Geoffrey Shea gshea@faculty.ocadu.ca
# ['Shearman,', 'Sam']
# Sam Shearman sshearman@ocadu.ca
# ['Sheedy,', 'Louise']
# Louise Sheedy lsheedy@faculty.ocadu.ca
# ['Sheppard,', 'Brian']
# Brian Sheppard bsheppard@faculty.ocadu.ca
# ['Sherman,', 'Ketzia']
# Ketzia Sherman ksherman@faculty.ocadu.ca
# ['Shick,', 'Nicholas']
# Nicholas Shick nshick@faculty.ocadu.ca
# ['Shimizu,', 'Leiko']
# Leiko Shimizu lshimizu@ocadu.ca
# ['Shire,', 'Bert']
# Bert Shire bshire@ocadu.ca
# ['Shoffner,', 'Terry']
# Terry Shoffner tshoffner@faculty.ocadu.ca
# ['Short,', 'Vilma']
# Vilma Short vshort@ocadu.ca
# ['Shuber,', 'Cassandra']
# Cassandra Shuber cshuber@faculty.ocadu.ca
# ['Shuebrook,', 'Ron']
# Ron Shuebrook No Email
# ['Siemens,', 'Luke']
# Luke Siemens lsiemens@faculty.ocadu.ca
# ['Sigurdson,', 'Victoria']
# Victoria Sigurdson vsigurdson@ocadu.ca
# ['Simms,', 'Alan']
# Alan Simms asimms@ocadu.ca
# ['Singer,', 'Christian']
# Christian Singer csinger@faculty.ocadu.ca
# ['Singh,', 'Meera']
# Meera Singh msingh@faculty.ocadu.ca
# ['Sloggett,', 'Paul']
# Paul Sloggett psloggett@faculty.ocadu.ca
# ['Smith,', 'Darren']
# Darren Smith dsmith@faculty.ocadu.ca
# ['Smith,', 'Dorie']
# Dorie Smith doriesmith@faculty.ocadu.ca
# ['Smith,', 'Greg']
# Greg Smith gsmith@faculty.ocadu.ca
# ['Smith,', 'Lisa']
# Lisa Smith ldsmith@ocadu.ca
# ['Smith,', 'Melissa']
# Melissa Smith melissasmith@faculty.ocadu.ca
# ['Smith,', 'Peter']
# Peter Smith psmith@faculty.ocadu.ca
# ['Smith,', 'Sean']
# Sean Smith seansmith@faculty.ocadu.ca
# ['Smolinski,', 'Richard']
# Richard Smolinski rsmolinski@faculty.ocadu.ca
# ['Smolinski,', 'Richard']
# Richard Smolinski rsmolinski@faculty.ocadu.ca
# ['Smyth,', 'Fiona']
# Fiona Smyth fsmyth@ocadu.ca
# ['Snack,', 'Geoff']
# Geoff Snack gsnack@faculty.ocadu.ca
# ['Sniderhan,', 'Sara']
# Sara Sniderhan ssniderhan@faculty.ocadu.ca
# ['Snow,', 'Nancy']
# Nancy Snow nsnow@faculty.ocadu.ca
# ['Snow,', 'Nancy']
# Nancy Snow nsnow@faculty.ocadu.ca
# ['So,', 'Vivian']
# Vivian So vso@ocadu.ca
# ['Solomon,', 'Daniel']
# Daniel Solomon dsolomon@faculty.ocadu.ca
# ['Somanath,', 'Sowmya']
# Sowmya Somanath ssomanath@faculty.ocadu.ca
# ['Sova,', 'Ilene']
# Ilene Sova isova@faculty.ocadu.ca
# ['Sova,', 'Ilene']
# Ilene Sova isova@faculty.ocadu.ca
# ['Spicanovic,', 'Vladimir']
# Vladimir Spicanovic vspicanovic@ocadu.ca
# ['Spicer,', 'Graeme']
# Graeme Spicer gspicer@faculty.ocadu.ca
# ['Sramek,', 'Peter']
# Peter Sramek psramek@faculty.ocadu.ca
# ['Staffieri,', 'Julie']
# Julie Staffieri jstaffieri@ocadu.ca
# ['Standing,', 'Jonathan']
# Jonathan Standing jstanding@faculty.ocadu.ca
# ['Steenbergen,', 'Eric']
# Eric Steenbergen esteenbergen@faculty.ocadu.ca
# ['Stein,', 'Suzanne']
# Suzanne Stein sstein@faculty.ocadu.ca
# ['Steventon,', 'Mike']
# Mike Steventon msteventon@faculty.ocadu.ca
# ['Stewart,', 'Nicole']
# Nicole Stewart nstewart@ocadu.ca
# ['Stone,', 'Graham']
# Graham Stone gstone@ocadu.ca
# ['Stott,', 'Cameron']
# Cameron Stott cstott@ocadu.ca
# ['Stranks,', 'Anna']
# Anna Stranks astranks@faculty.ocadu.ca
# ['Strapps,', 'Kate']
# Kate Strapps kstrapps@ocadu.ca
# ['Straun,', 'Lancelot']
# Lancelot Straun lstraun@ocadu.ca
# ['Stuart,', 'Elisabeth']
# Elisabeth Stuart bstuart@faculty.ocadu.ca
# ['Suddick,', 'Jennie']
# Jennie Suddick jsuddick@ocadu.ca
# ['Suen,', 'Victoria']
# Victoria Suen vsuen@faculty.ocadu.ca
# ['Sullivan,', 'Derek']
# Derek Sullivan dsullivan@faculty.ocadu.ca
# ['Suzuki,', 'Anna']
# Anna Suzuki asuzuki@ocadu.ca
# ['Swartz,', 'Amy']
# Amy Swartz aswartz@faculty.ocadu.ca
# ['Szkudlarek,', 'Veronika']
# Veronika Szkudlarek vszkudlarek@faculty.ocadu.ca
# ['Takeuchi,', 'Glen']
# Glen Takeuchi gtakeuchi@faculty.ocadu.ca
# ['Talei,', 'Leila']
# Leila Talei ltalei@ocadu.ca
# ['Tamayo,', 'Alejandro']
# Alejandro Tamayo atamayo@faculty.ocadu.ca
# ['Tao,', 'Di']
# Di Tao dtao@faculty.ocadu.ca
# ['Tapper,', 'Evan']
# Evan Tapper etapper@ocadu.ca
# ['Taxali,', 'Gary']
# Gary Taxali gtaxali@faculty.ocadu.ca
# ['Teixeira,', 'Robert']
# Robert Teixeira rteixeira@faculty.ocadu.ca
# ['Tekson,', 'Oz', 'John']
# Oz Tekson otekson@faculty.ocadu.ca
# ['Telford-Keogh,', 'Catherine']
# Catherine Telford-Keogh ctelfordkeogh@faculty.ocadu.ca
# ['Therrien,', 'Marie', 'Josee']
# Marie Therrien mtherrien@ocadu.ca
# ['Third,', 'Tom']
# Tom Third tomthird@faculty.ocadu.ca
# ['Thiruchelvam,', 'Roshan']
# Roshan Thiruchelvam operations@ocadsu.org
# ['Thompson,', 'Christopher']
# Christopher Thompson cthompson@ocadu.ca
# ['Thompson,', 'Julie']
# Julie Thompson juliethompson@ocadu.ca
# ['Thorne,', 'David']
# David Thorne dthorne@faculty.ocadu.ca
# ['Thorne,', 'Kika']
# Kika Thorne kthorne@faculty.ocadu.ca
# ['Tieu,', 'Robin']
# Robin Tieu rtieu@faculty.ocadu.ca
# ['Tieu,', 'Robin']
# Robin Tieu rtieu@faculty.ocadu.ca
# ['Tindale,', 'Adam']
# Adam Tindale atindale@faculty.ocadu.ca
# ['Todd,', 'Jonathan']
# Jonathan Todd jtodd@faculty.ocadu.ca
# ['Tomic,', 'Milena']
# Milena Tomic mtomic@faculty.ocadu.ca
# ['Tonizzo,', 'Davide']
# Davide Tonizzo dtonizzo@faculty.ocadu.ca
# ['Toromoreno,', 'Louis']
# Louis Toromoreno ltoromoreno@ocadu.ca
# ['Traill,', 'Mary']
# Mary Traill mtraill@faculty.ocadu.ca
# ['Tranum,', 'Sarah']
# Sarah Tranum stranum@faculty.ocadu.ca
# ['Treviranus,', 'Jutta']
# Jutta Treviranus jtreviranus@faculty.ocadu.ca
# ['Treviranus,', 'Jutta']
# Jutta Treviranus jtreviranus@faculty.ocadu.ca
# ['Trommer,', 'Michael']
# Michael Trommer mtrommer@faculty.ocadu.ca
# ['Tsang,', 'Linda']
# Linda Tsang ltsang@ocadu.ca
# ['Tse,', 'Winna']
# Winna Tse wtse@ocadu.ca
# ['Tudela,', 'Juan', 'Carlos']
# Juan Tudela jtudela@faculty.ocadu.ca
# ['Tuer,', 'Dot']
# Dot Tuer dtuer@faculty.ocadu.ca
# ['Tulett,', 'Kelly']
# Kelly Tulett ktulett@faculty.ocadu.ca
# ['Tulk,', 'Stephen']
# Stephen Tulk stulk@faculty.ocadu.ca
# ['Tung,', 'Annie']
# Annie Tung annietung@faculty.ocadu.ca
# ['Tunstall,', 'Dori']
# Dori Tunstall dtunstall@ocadu.ca
# ['Tutt,', 'Jeff']
# Jeff Tutt jtutt@faculty.ocadu.ca
# ['Uchida,', 'Robin']
# Robin Uchida ruchida@faculty.ocadu.ca
# ['Unger,', 'Philip']
# Philip Unger punger@faculty.ocadu.ca
# ['Urban,', 'Ann']
# Ann Urban aurban@faculty.ocadu.ca
# ['Vaisberg,', 'Igor']
# Igor Vaisberg ivaisberg@ocadu.ca
# ['Valencia,', 'Oliver']
# Oliver Valencia ovalencia@ocadu.ca
# ['Van', 'Alstyne,', 'Greg']
# Alstyne, Va gvanalstyne@faculty.ocadu.ca
# ['Van', 'Dongen,', 'Paul']
# Dongen, Va pvandongen@faculty.ocadu.ca
# ['van', 'Heuvelen,', 'Couzyn']
# Heuvelen, va cvanheuvelen@faculty.ocadu.ca
# ['Van', 'Leeuwen,', 'Annette']
# Leeuwen, Va avanleeuwen@faculty.ocadu.ca
# ['Van', 'Ziffle,', 'Eric']
# Ziffle, Va evanziffle@faculty.ocadu.ca
# ['Vanderborght,', 'Karen']
# Karen Vanderborght kvanderborght@faculty.ocadu.ca
# ...
# 20                       0.019968                0.048734
# 21                       0.000986                0.013745
# 22                       0.184380                0.196583
# 23                       0.058069                0.043394
# 24                       0.000868                0.010133
# 25                       0.134115                0.014492
# 26                       0.011756                0.041652
# 27                       0.008012                0.345674
# 28                       0.017885                0.027099
# 29                       0.002789                0.021183
# ..                            ...                     ...
# 831                      0.002656                0.026888
# 833                      0.013071                0.232157
# 834                      0.005156                0.087605
# 836                      0.000461                0.017547
# 837                      0.000599                0.008247
# 838                      0.004370                0.085706
# 839                      0.016943                0.119223
# 840                      0.011090                0.175479
# 841                      0.882264                0.066786
# 842                      0.004200                0.004652
# 843                      0.000468                0.000564
# 844                      0.004863                0.003906
# 845                      0.000169                0.000953
# 846                      0.001191                0.104433
# 847                      0.000658                0.021997
# 848                      0.011905                0.273612
# 850                      0.004825                0.002216
# 851                      0.017293                0.001435
# 852                      0.000252                0.001560
# 853                      0.000857                0.000508
# 854                      0.004457                0.013325
# 855                      0.002444                0.050956
# 856                      0.007230                0.027989
# 857                      0.007219                0.101794
# 858                      0.403853                0.347483
# 859                      0.002572                0.000793
# 860                      0.000767                0.001599
# 861                      0.000020                0.000073
# 862                      0.022905                0.516174
# 863                      0.232531                0.091102
#
#      GreaterEuropean,WestEuropean,French  \
# 0                               0.005517
# 1                               0.019454
# 2                               0.042619
# 3                               0.039857
# 4                               0.015258
# 5                               0.044085
# 6                               0.007441
# 7                               0.015181
# 8                               0.020921
# 9                               0.045404
# 10                              0.006290
# 11                              0.009537
# 12                              0.031824
# 13                              0.360864
# 14                              0.004684
# 15                              0.013882
# 16                              0.038530
# 17                              0.015600
# 18                              0.004987
# 19                              0.024662
# 20                              0.153491
# 21                              0.030841
# 22                              0.009525
# 23                              0.006070
# 24                              0.004949
# 25                              0.017671
# 26                              0.266188
# 27                              0.045668
# 28                              0.033048
# 29                              0.021855
# ..                                   ...
# 831                             0.005700
# 833                             0.030793
# 834                             0.037683
# 836                             0.010944
# 837                             0.005500
# 838                             0.013577
# 839                             0.020220
# 840                             0.024182
# 841                             0.002861
# 842                             0.005623
# 843                             0.001540
# 844                             0.001342
# 845                             0.000248
# 846                             0.016517
# 847                             0.010191
# 848                             0.031554
# 850                             0.000839
# 851                             0.001221
# 852                             0.000120
# 853                             0.000149
# 854                             0.005063
# 855                             0.002169
# 856                             0.017439
# 857                             0.027752
# 858                             0.009560
# 859                             0.000422
# 860                             0.000243
# 861                             0.000014
# 862                             0.013926
# 863                             0.049445
#
#      GreaterEuropean,WestEuropean,Germanic  \
# 0                                 0.001368
# 1                                 0.003024
# 2                                 0.033203
# 3                                 0.023124
# 4                                 0.006666
# 5                                 0.046930
# 6                                 0.003168
# 7                                 0.011435
# 8                                 0.004240
# 9                                 0.002576
# 10                                0.049348
# 11                                0.004068
# 12                                0.007311
# 13                                0.009161
# 14                                0.000727
# 15                                0.005444
# 16                                0.007430
# 17                                0.006262
# 18                                0.000600
# 19                                0.092377
# 20                                0.004822
# 21                                0.001262
# 22                                0.134809
# 23                                0.005610
# 24                                0.003055
# 25                                0.030244
# 26                                0.007930
# 27                                0.008322
# 28                                0.015309
# 29                                0.003737
# ..                                     ...
# 831                               0.001985
# 833                               0.062074
# 834                               0.004468
# 836                               0.000394
# 837                               0.002802
# 838                               0.003702
# 839                               0.021246
# 840                               0.092339
# 841                               0.002871
# 842                               0.000463
# 843                               0.000248
# 844                               0.001681
# 845                               0.000248
# 846                               0.005441
# 847                               0.001196
# 848                               0.021156
# 850                               0.000155
# 851                               0.005354
# 852                               0.000248
# 853                               0.000450
# 854                               0.007726
# 855                               0.001874
# 856                               0.001799
# 857                               0.005218
# 858                               0.014269
# 859                               0.000229
# 860                               0.000127
# 861                               0.000009
# 862                               0.243517
# 863                               0.007853
#
#      GreaterEuropean,WestEuropean,Hispanic  \
# 0                                 0.003158
# 1                                 0.007313
# 2                                 0.058186
# 3                                 0.059051
# 4                                 0.009015
# 5                                 0.014149
# 6                                 0.005529
# 7                                 0.006601
# 8                                 0.046077
# 9                                 0.023029
# 10                                0.012773
# 11                                0.009332
# 12                                0.021209
# 13                                0.027447
# 14                                0.974791
# 15                                0.108279
# 16                                0.007910
# 17                                0.035802
# 18                                0.942153
# 19                                0.145755
# 20                                0.013112
# 21                                0.004765
# 22                                0.018878
# 23                                0.010515
# 24                                0.891434
# 25                                0.392754
# 26                                0.194174
# 27                                0.249853
# 28                                0.066356
# 29                                0.236507
# ..                                     ...
# 831                               0.010876
# 833                               0.027147
# 834                               0.011491
# 836                               0.004413
# 837                               0.004596
# 838                               0.007399
# 839                               0.011407
# 840                               0.007255
# 841                               0.010600
# 842                               0.002481
# 843                               0.000485
# 844                               0.002121
# 845                               0.000226
# 846                               0.015956
# 847                               0.011060
# 848                               0.052639
# 850                               0.002601
# 851                               0.001357
# 852                               0.000461
# 853                               0.004170
# 854                               0.004887
# 855                               0.007183
# 856                               0.007451
# 857                               0.005238
# 858                               0.018640
# 859                               0.000989
# 860                               0.000560
# 861                               0.000069
# 862                               0.011909
# 863                               0.013737
#
#      GreaterEuropean,WestEuropean,Italian  GreaterEuropean,WestEuropean,Nordic
# 0                                0.003812                             0.002301
# 1                                0.010379                             0.002376
# 2                                0.075301                             0.013387
# 3                                0.327682                             0.033170
# 4                                0.022471                             0.000798
# 5                                0.011338                             0.128452
# 6                                0.002327                             0.002518
# 7                                0.004356                             0.004643
# 8                                0.014022                             0.003480
# 9                                0.030714                             0.012286
# 10                               0.005543                             0.418331
# 11                               0.007954                             0.004331
# 12                               0.021650                             0.006236
# 13                               0.200998                             0.001881
# 14                               0.008124                             0.000081
# 15                               0.022815                             0.001864
# 16                               0.002586                             0.007904
# 17                               0.022961                             0.076024
# 18                               0.008945                             0.000088
# 19                               0.267370                             0.013561
# 20                               0.006553                             0.006318
# 21                               0.016913                             0.002143
# 22                               0.012889                             0.215119
# 23                               0.006806                             0.015056
# 24                               0.060113                             0.000392
# 25                               0.049218                             0.137870
# 26                               0.099514                             0.029010
# 27                               0.046301                             0.006196
# 28                               0.050184                             0.015824
# 29                               0.270582                             0.002825
# ..                                    ...                                  ...
# 831                              0.006283                             0.007652
# 833                              0.013636                             0.018455
# 834                              0.003755                             0.001535
# 836                              0.007117                             0.000394
# 837                              0.001703                             0.002322
# 838                              0.004550                             0.003571
# 839                              0.009520                             0.046569
# 840                              0.006405                             0.002598
# 841                              0.012721                             0.000951
# 842                              0.001255                             0.000481
# 843                              0.000679                             0.000623
# 844                              0.003446                             0.000320
# 845                              0.000501                             0.000072
# 846                              0.005757                             0.001556
# 847                              0.002994                             0.002313
# 848                              0.027425                             0.007956
# 850                              0.000623                             0.000618
# 851                              0.001623                             0.007610
# 852                              0.000349                             0.000089
# 853                              0.000101                             0.000071
# 854                              0.001877                             0.004625
# 855                              0.005019                             0.002866
# 856                              0.006470                             0.004642
# 857                              0.029740                             0.021894
# 858                              0.019207                             0.006752
# 859                              0.000364                             0.000104
# 860                              0.000320                             0.000056
# 861                              0.000010                             0.000002
# 862                              0.017778                             0.023771
# 863                              0.022618                             0.006755
#
# [818 rows x 17 columns]
